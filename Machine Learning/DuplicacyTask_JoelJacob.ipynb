# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Dupdf.csv')

# %%
df.head()
# Out:
#      Name  Age  Course  Name.1
# 0   Joel     18    CSE   Joel
# 1   Adam     20    ECE   Adam
# 2  Rachel    19     ME  Rachel
# 3    Paul    21     CE    Paul
# 4   Joel     18    CSE   Joel

# %%
df2=df.drop_duplicates() #removing duplicate rows

# %%
df2
# Out:
#      Name  Age  Course  Name.1
# 0   Joel     18    CSE   Joel
# 1   Adam     20    ECE   Adam
# 2  Rachel    19     ME  Rachel
# 3    Paul    21     CE    Paul

# %%
df1=df.T.drop_duplicates().T #removing duplicate columns

# %%
df1
# Out:
#      Name Age  Course
# 0   Joel    18    CSE
# 1   Adam    20    ECE
# 2  Rachel   19     ME
# 3    Paul   21     CE
# 4   Joel    18    CSE

# %%
sns.countplot(x='Name', data=df)
plt.show()
