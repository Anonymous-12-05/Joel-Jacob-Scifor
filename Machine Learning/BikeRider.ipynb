# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('202211-divvy-tripdata.csv')

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  BCC66FC6FAB27CC7  electric_bike  2022-11-10 06:21:55  2022-11-10 06:31:27
# 1  772AB67E902C180F   classic_bike  2022-11-04 07:31:55  2022-11-04 07:46:25
# 2  585EAD07FDEC0152   classic_bike  2022-11-21 17:20:29  2022-11-21 17:34:36
# 3  91C4E7ED3C262FF9   classic_bike  2022-11-25 17:29:34  2022-11-25 17:45:15
# 4  709206A3104CABC8   classic_bike  2022-11-29 17:24:25  2022-11-29 17:42:51
#
#            start_station_name start_station_id        end_station_name  \
# 0         Canal St & Adams St            13011  St. Clair St & Erie St
# 1         Canal St & Adams St            13011  St. Clair St & Erie St
# 2  Indiana Ave & Roosevelt Rd           SL-005  St. Clair St & Erie St
# 3  Indiana Ave & Roosevelt Rd           SL-005  St. Clair St & Erie St
# 4  Indiana Ave & Roosevelt Rd           SL-005  St. Clair St & Erie St
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
len(df['rideable_type'].unique())
# Out:
# 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164746 entries, 0 to 164745
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             164746 non-null  object
#  1   rideable_type       164746 non-null  object
#  2   started_at          164746 non-null  object
#  3   ended_at            164746 non-null  object
#  4   start_station_name  142287 non-null  object
#  5   start_station_id    142287 non-null  object
#  6   end_station_name    164746 non-null  object
#  7   end_station_id      164746 non-null  object
#  8   start_lat           164746 non-null  float64
#  9   start_lng           164745 non-null  float64
#  10  end_lat             164745 non-null  float64
#  11  end_lng             164745 non-null  float64
#  12  member_casual       164745 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 16.3+ MB

# %%
df.isna()
# Out:
#         ride_id  rideable_type  started_at  ended_at  start_station_name  \
# 0         False          False       False     False               False
# 1         False          False       False     False               False
# 2         False          False       False     False               False
# 3         False          False       False     False               False
# 4         False          False       False     False               False
# ...         ...            ...         ...       ...                 ...
# 164741    False          False       False     False               False
# 164742    False          False       False     False               False
# 164743    False          False       False     False               False
# 164744    False          False       False     False               False
# 164745    False          False       False     False               False
#
#         start_station_id  end_station_name  end_station_id  start_lat  \
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >
